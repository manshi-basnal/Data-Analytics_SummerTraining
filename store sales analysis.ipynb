# %% [markdown]
# # ********* Store Sales Snalysis *********

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\data set\store_sales.csv")
print("Original Dataset:")
df
# Out:
# Original Dataset:
#             date  store   sales  promo  holiday
# 0     2022-01-01      1  184.78      0        0
# 1     2022-01-02      1  192.62      0        0
# 2     2022-01-03      1  212.68      0        0
# 3     2022-01-04      1  249.58      1        0
# 4     2022-01-05      1  223.50      0        0
# ...          ...    ...     ...    ...      ...
# 7295  2023-12-27     10  242.08      0        0
# 7296  2023-12-28     10  235.35      0        0
# 7297  2023-12-29     10  222.82      0        0
# 7298  2023-12-30     10  236.04      1        0
# 7299  2023-12-31     10  208.29      0        0
#
# [7300 rows x 5 columns]

# %%
print(df)
# Out:
#             date  store   sales  promo  holiday
# 0     2022-01-01      1  184.78      0        0
# 1     2022-01-02      1  192.62      0        0
# 2     2022-01-03      1  212.68      0        0
# 3     2022-01-04      1  249.58      1        0
# 4     2022-01-05      1  223.50      0        0
# ...          ...    ...     ...    ...      ...
# 7295  2023-12-27     10  242.08      0        0
# 7296  2023-12-28     10  235.35      0        0
# 7297  2023-12-29     10  222.82      0        0
# 7298  2023-12-30     10  236.04      1        0
# 7299  2023-12-31     10  208.29      0        0
#
# [7300 rows x 5 columns]

# %%
print(df.tail())
# Out:
#             date  store   sales  promo  holiday
# 7295  2023-12-27     10  242.08      0        0
# 7296  2023-12-28     10  235.35      0        0
# 7297  2023-12-29     10  222.82      0        0
# 7298  2023-12-30     10  236.04      1        0
# 7299  2023-12-31     10  208.29      0        0

# %%
print(df.shape)
# Out:
# (7300, 5)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=7300, step=1)

# %%
print(df.columns)
# Out:
# Index(['date', 'store', 'sales', 'promo', 'holiday'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7300 entries, 0 to 7299
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     7300 non-null   object
#  1   store    7300 non-null   int64
#  2   sales    7300 non-null   float64
#  3   promo    7300 non-null   int64
#  4   holiday  7300 non-null   int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 285.3+ KB
# None

# %%
print(df.describe())
# Out:
#              store        sales        promo      holiday
# count  7300.000000  7300.000000  7300.000000  7300.000000
# mean      5.500000   228.434571     0.202192     0.104110
# std       2.872478    26.625636     0.401662     0.305424
# min       1.000000   160.710000     0.000000     0.000000
# 25%       3.000000   209.217500     0.000000     0.000000
# 50%       5.500000   226.795000     0.000000     0.000000
# 75%       8.000000   245.590000     0.000000     0.000000
# max      10.000000   340.730000     1.000000     1.000000

# %%
print(df['date'].dtype)
# Out:
# object

# %%
df['date'] = pd.to_datetime(df['date'])
print(df.head())
# Out:
#         date  store   sales  promo  holiday
# 0 2022-01-01      1  184.78      0        0
# 1 2022-01-02      1  192.62      0        0
# 2 2022-01-03      1  212.68      0        0
# 3 2022-01-04      1  249.58      1        0
# 4 2022-01-05      1  223.50      0        0

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
print(df.head())
# Out:
#         date  store   sales  promo  holiday  year  month
# 0 2022-01-01      1  184.78      0        0  2022      1
# 1 2022-01-02      1  192.62      0        0  2022      1
# 2 2022-01-03      1  212.68      0        0  2022      1
# 3 2022-01-04      1  249.58      1        0  2022      1
# 4 2022-01-05      1  223.50      0        0  2022      1

# %%
df['days_diff'] = df['date'] - df['date'].min()
print(df.head())
# Out:
#         date  store   sales  promo  holiday  year  month days_diff
# 0 2022-01-01      1  184.78      0        0  2022      1    0 days
# 1 2022-01-02      1  192.62      0        0  2022      1    1 days
# 2 2022-01-03      1  212.68      0        0  2022      1    2 days
# 3 2022-01-04      1  249.58      1        0  2022      1    3 days
# 4 2022-01-05      1  223.50      0        0  2022      1    4 days

# %%
print(df['date'].dtype)
# Out:
# datetime64[ns]

# %%
print(df.isnull().sum())
# Out:
# date         0
# store        0
# sales        0
# promo        0
# holiday      0
# year         0
# month        0
# days_diff    0
# dtype: int64

# %%
print(df['sales'].describe())
# Out:
# count    7300.000000
# mean      228.434571
# std        26.625636
# min       160.710000
# 25%       209.217500
# 50%       226.795000
# 75%       245.590000
# max       340.730000
# Name: sales, dtype: float64

# %%
print(df.loc[0])
# Out:
# date         2022-01-01 00:00:00
# store                          1
# sales                     184.78
# promo                          0
# holiday                        0
# year                        2022
# month                          1
# days_diff        0 days 00:00:00
# Name: 0, dtype: object

# %%
print(df.iloc[1])
# Out:
# date         2022-01-02 00:00:00
# store                          1
# sales                     192.62
# promo                          0
# holiday                        0
# year                        2022
# month                          1
# days_diff        1 days 00:00:00
# Name: 1, dtype: object

# %%
print(df[df['sales'] > 200])
# Out:
#            date  store   sales  promo  holiday  year  month days_diff
# 2    2022-01-03      1  212.68      0        0  2022      1    2 days
# 3    2022-01-04      1  249.58      1        0  2022      1    3 days
# 4    2022-01-05      1  223.50      0        0  2022      1    4 days
# 5    2022-01-06      1  221.79      0        0  2022      1    5 days
# 6    2022-01-07      1  200.43      0        0  2022      1    6 days
# ...         ...    ...     ...    ...      ...   ...    ...       ...
# 7295 2023-12-27     10  242.08      0        0  2023     12  725 days
# 7296 2023-12-28     10  235.35      0        0  2023     12  726 days
# 7297 2023-12-29     10  222.82      0        0  2023     12  727 days
# 7298 2023-12-30     10  236.04      1        0  2023     12  728 days
# 7299 2023-12-31     10  208.29      0        0  2023     12  729 days
#
# [6276 rows x 8 columns]

# %%
print(df[(df['sales'] > 200) & (df['holiday'] == 0)])
# Out:
#            date  store   sales  promo  holiday  year  month days_diff
# 2    2022-01-03      1  212.68      0        0  2022      1    2 days
# 3    2022-01-04      1  249.58      1        0  2022      1    3 days
# 4    2022-01-05      1  223.50      0        0  2022      1    4 days
# 5    2022-01-06      1  221.79      0        0  2022      1    5 days
# 6    2022-01-07      1  200.43      0        0  2022      1    6 days
# ...         ...    ...     ...    ...      ...   ...    ...       ...
# 7295 2023-12-27     10  242.08      0        0  2023     12  725 days
# 7296 2023-12-28     10  235.35      0        0  2023     12  726 days
# 7297 2023-12-29     10  222.82      0        0  2023     12  727 days
# 7298 2023-12-30     10  236.04      1        0  2023     12  728 days
# 7299 2023-12-31     10  208.29      0        0  2023     12  729 days
#
# [5516 rows x 8 columns]

# %%
print(df[(df['store'] == 1) & (df['sales'] > 200) & (df['promo'] == 1)])
# Out:
#           date  store   sales  promo  holiday  year  month days_diff
# 3   2022-01-04      1  249.58      1        0  2022      1    3 days
# 7   2022-01-08      1  213.47      1        0  2022      1    7 days
# 8   2022-01-09      1  222.44      1        0  2022      1    8 days
# 13  2022-01-14      1  218.31      1        0  2022      1   13 days
# 31  2022-02-01      1  252.09      1        0  2022      2   31 days
# ..         ...    ...     ...    ...      ...   ...    ...       ...
# 722 2023-12-24      1  259.15      1        0  2023     12  722 days
# 724 2023-12-26      1  285.88      1        0  2023     12  724 days
# 725 2023-12-27      1  290.81      1        0  2023     12  725 days
# 727 2023-12-29      1  259.94      1        0  2023     12  727 days
# 729 2023-12-31      1  256.76      1        0  2023     12  729 days
#
# [153 rows x 8 columns]

# %%
print(df.drop('promo', axis=1, inplace=True))
# Out:
# None

# %%
print(df.drop(1, axis=0, inplace=True))
# Out:
# None

# %%
print(df.sort_values(by='sales'))
# Out:
#            date  store   sales  holiday  year  month days_diff
# 6612 2022-02-12     10  160.71        0  2022      2   42 days
# 1467 2022-01-08      3  162.24        0  2022      1    7 days
# 1579 2022-04-30      3  165.72        0  2022      4  119 days
# 6570 2022-01-01     10  165.84        0  2022      1    0 days
# 1495 2022-02-05      3  166.41        0  2022      2   35 days
# ...         ...    ...     ...      ...   ...    ...       ...
# 2564 2023-01-10      4  326.00        1  2023      1  374 days
# 6222 2023-01-18      9  326.64        1  2023      1  382 days
# 5084 2023-12-06      7  327.46        1  2023     12  704 days
# 6559 2023-12-21      9  328.26        1  2023     12  719 days
# 6516 2023-11-08      9  340.73        1  2023     11  676 days
#
# [7299 rows x 7 columns]

# %%
print(df.sort_values(by='sales', ascending=False))
# Out:
#            date  store   sales  holiday  year  month days_diff
# 6516 2023-11-08      9  340.73        1  2023     11  676 days
# 6559 2023-12-21      9  328.26        1  2023     12  719 days
# 5084 2023-12-06      7  327.46        1  2023     12  704 days
# 6222 2023-01-18      9  326.64        1  2023      1  382 days
# 2564 2023-01-10      4  326.00        1  2023      1  374 days
# ...         ...    ...     ...      ...   ...    ...       ...
# 1495 2022-02-05      3  166.41        0  2022      2   35 days
# 6570 2022-01-01     10  165.84        0  2022      1    0 days
# 1579 2022-04-30      3  165.72        0  2022      4  119 days
# 1467 2022-01-08      3  162.24        0  2022      1    7 days
# 6612 2022-02-12     10  160.71        0  2022      2   42 days
#
# [7299 rows x 7 columns]

# %%
print(df.groupby('sales')['year'].mean())
# Out:
# sales
# 160.71    2022.0
# 162.24    2022.0
# 165.72    2022.0
# 165.84    2022.0
# 166.41    2022.0
#            ...
# 326.00    2023.0
# 326.64    2023.0
# 327.46    2023.0
# 328.26    2023.0
# 340.73    2023.0
# Name: year, Length: 5162, dtype: float64

# %%
plt.plot(df['date'], df['sales'], color='green', linestyle='--', marker='o')
plt.title("line plot example")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.bar(df['store'], df['sales'], color='red')
plt.title("Bar chart")
plt.show()

# %%
plt.barh(df['store'], df['sales'], color='red')
plt.title("Bar chart")
plt.show()

# %%
plt.scatter(df['store'], df['sales'], color='red')
plt.title("scatter plot")
plt.show()

# %%
plt.hist(df['sales'], bins=20, color='orange')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Sales Distribution')
plt.show()

# %%
sales = df.sales
labels=['sales']
sizes=[20]
plt.pie(sizes, labels=labels , autopct='%1.1f%%', startangle=90)
plt.title("Pie chart")
plt.show()

# %%
plt.figure(figsize=(10,5))

# Subplot 1: Line plot
plt.subplot(1, 2, 1)
plt.plot(df['date'], df['sales'], color='blue')
plt.title('Sales Over Time')
plt.xticks(rotation=45)

# Subplot 2: Histogram
plt.subplot(1, 2, 2)
plt.hist(df['sales'], bins=10, color='orange', edgecolor='black')
plt.title('Sales Distribution')

plt.tight_layout()
plt.show()

# %%
holiday_sales = df[df['holiday'] == 1].groupby('store')['sales'].sum()
nonholiday_sales = df[df['holiday'] == 0].groupby('store')['sales'].sum()

# Ensure same order of stores
stores = nonholiday_sales.index

plt.figure(figsize=(8,5))

# Non-holiday sales as base
plt.bar(stores, nonholiday_sales, label='Non-Holiday Sales', color='skyblue')

# Holiday sales stacked on top
plt.bar(stores, holiday_sales, bottom=nonholiday_sales, label='Holiday Sales', color='lightgreen')

# Labels and title
plt.xlabel('Store')
plt.ylabel('Total Sales')
plt.title('Stacked Bar Chart: Holiday vs Non-Holiday Sales')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.boxplot(df['sales'])
plt.ylabel('Sales')
plt.title('Box Plot of Sales')
plt.show()

# %%
df = df.sort_values('date')

x = df['date']
y = df['sales']
plt.figure(figsize=(10,5))
plt.plot(x, y, color='blue', label='Sales')
plt.fill_between(x, y, color='lightblue', alpha=0.5)  # Fill area under sales curve
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Over Time (Fill Between)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
grouped = df.groupby('store')['sales']
mean_sales = grouped.mean()
std_sales = grouped.std()

plt.figure(figsize=(8,5))
plt.bar(mean_sales.index, mean_sales.values, yerr=std_sales.values,
        capsize=5, color='lightgreen', edgecolor='black')

plt.xlabel('Store')
plt.ylabel('Average Sales')
plt.title('Average Sales per Store with Error Bars (Std Dev)')
plt.tight_layout()
plt.show()
